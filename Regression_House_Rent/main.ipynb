# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Read Data

# %%
data=pd.read_csv("/kaggle/input/house-rent-prediction-dataset/House_Rent_Dataset.csv")
data
# Out:
#        Posted On  BHK   Rent  Size            Floor    Area Type  \
# 0     2022-05-18    2  10000  1100  Ground out of 2   Super Area
# 1     2022-05-13    2  20000   800       1 out of 3   Super Area
# 2     2022-05-16    2  17000  1000       1 out of 3   Super Area
# 3     2022-07-04    2  10000   800       1 out of 2   Super Area
# 4     2022-05-09    2   7500   850       1 out of 2  Carpet Area
# ...          ...  ...    ...   ...              ...          ...
# 4741  2022-05-18    2  15000  1000       3 out of 5  Carpet Area
# 4742  2022-05-15    3  29000  2000       1 out of 4   Super Area
# 4743  2022-07-10    3  35000  1750       3 out of 5  Carpet Area
# 4744  2022-07-06    3  45000  1500     23 out of 34  Carpet Area
# 4745  2022-05-04    2  15000  1000       4 out of 5  Carpet Area
#
#                  Area Locality       City Furnishing Status  Tenant Preferred  \
# 0                       Bandel    Kolkata       Unfurnished  Bachelors/Family
# ...

# %%
data.head()
# Out:
#     Posted On  BHK   Rent  Size            Floor    Area Type  \
# 0  2022-05-18    2  10000  1100  Ground out of 2   Super Area
# 1  2022-05-13    2  20000   800       1 out of 3   Super Area
# 2  2022-05-16    2  17000  1000       1 out of 3   Super Area
# 3  2022-07-04    2  10000   800       1 out of 2   Super Area
# 4  2022-05-09    2   7500   850       1 out of 2  Carpet Area
#
#               Area Locality     City Furnishing Status  Tenant Preferred  \
# 0                    Bandel  Kolkata       Unfurnished  Bachelors/Family
# 1  Phool Bagan, Kankurgachi  Kolkata    Semi-Furnished  Bachelors/Family
# 2   Salt Lake City Sector 2  Kolkata    Semi-Furnished  Bachelors/Family
# 3               Dumdum Park  Kolkata       Unfurnished  Bachelors/Family
# 4             South Dum Dum  Kolkata       Unfurnished         Bachelors
#
#    Bathroom Point of Contact
# 0         2    Contact Owner
# 1         1    Contact Owner
# 2         1    Contact Owner
# 3         1    Contact Owner
# ...

# %% [markdown]
# # Data Describe

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4746 entries, 0 to 4745
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Posted On          4746 non-null   object
#  1   BHK                4746 non-null   int64
#  2   Rent               4746 non-null   int64
#  3   Size               4746 non-null   int64
#  4   Floor              4746 non-null   object
#  5   Area Type          4746 non-null   object
#  6   Area Locality      4746 non-null   object
#  7   City               4746 non-null   object
#  8   Furnishing Status  4746 non-null   object
#  9   Tenant Preferred   4746 non-null   object
#  10  Bathroom           4746 non-null   int64
#  11  Point of Contact   4746 non-null   object
# dtypes: int64(4), object(8)
# memory usage: 445.1+ KB

# %%
data.describe().T
# Out:
#            count          mean           std     min      25%      50%  \
# BHK       4746.0      2.083860      0.832256     1.0      2.0      2.0
# Rent      4746.0  34993.451327  78106.412937  1200.0  10000.0  16000.0
# Size      4746.0    967.490729    634.202328    10.0    550.0    850.0
# Bathroom  4746.0      1.965866      0.884532     1.0      1.0      2.0
#
#               75%        max
# BHK           3.0        6.0
# Rent      33000.0  3500000.0
# Size       1200.0     8000.0
# Bathroom      2.0       10.0

# %% [markdown]
# # Check The null values

# %%
sns.heatmap( data.isnull(),cmap=sns.cubehelix_palette(as_cmap=True))
# Out:
# <AxesSubplot:>

# %%
data.isnull().sum()
# Out:
# Posted On            0
# BHK                  0
# Rent                 0
# Size                 0
# Floor                0
# Area Type            0
# Area Locality        0
# City                 0
# Furnishing Status    0
# Tenant Preferred     0
# Bathroom             0
# Point of Contact     0
# dtype: int64

# %% [markdown]
# there is no null values

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Data visualization

# %%
data.hist(bins = 10 , figsize= (14,10))
plt.show()

# %%
data.plot(kind = "box" , subplots = True , figsize = (25,15) , layout = (5,5))
# Out:
# BHK            AxesSubplot(0.125,0.747241;0.133621x0.132759)
# Rent        AxesSubplot(0.285345,0.747241;0.133621x0.132759)
# Size         AxesSubplot(0.44569,0.747241;0.133621x0.132759)
# Bathroom    AxesSubplot(0.606034,0.747241;0.133621x0.132759)
# dtype: object

# %%
fig = px.pie(data, names='Furnishing Status', title='Furnishing Status',color_discrete_sequence=px.colors.sequential.YlGnBu)
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.18.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ...

# %% [markdown]
# 47% of the Houses are Semi Furnished. 38% of the Houses are Unfurnished. Rest of the Houses are Furnished.

# %%
fig = px.pie(data, names='Tenant Preferred', title='Tenant Preferred',color_discrete_sequence=px.colors.sequential.RdBu)
fig.show()
# Out:
# <div>                            <div id="6892365b-3663-4877-b4cc-05b144b22e5d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6892365b-3663-4877-b4cc-05b144b22e5d")) {                    Plotly.newPlot(                        "6892365b-3663-4877-b4cc-05b144b22e5d",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Tenant Preferred=%{label}<extra></extra>","labels":["Bachelors/Family","Bachelors/Family","Bachelors/Family","Bachelors/Family","Bachelors","Bachelors/Family","Bachelors","Bachelors","Bachelors","Bachelors/Family","Bachelors/Family","Bachelors/Family","Bachelors","Bachelors/Family","Bachelors","Bachelors/Family","Bachelors/Family","Bachelors/Family","Bachelors/Family","Bachelors/Family","Family","Bachelors"
# ...

# %% [markdown]
# The most tenant preferred is bachelors/family

# %%
data['Furnishing Status'].value_counts()
# Out:
# Semi-Furnished    2251
# Unfurnished       1815
# Furnished          680
# Name: Furnishing Status, dtype: int64

# %%
fig = px.pie(data, values='Rent', names='Furnishing Status', color='Furnishing Status',
             color_discrete_map={'Semi-Furnished':'cyan',
                                 'Unfurnished':'royalblue',
                                 'Furnished':'darkblue'})
fig.show()
# Out:
# <div>                            <div id="881a33df-fac3-443c-8198-e41f25f9b714" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("881a33df-fac3-443c-8198-e41f25f9b714")) {                    Plotly.newPlot(                        "881a33df-fac3-443c-8198-e41f25f9b714",                        [{"customdata":[["Unfurnished"],["Semi-Furnished"],["Semi-Furnished"],["Unfurnished"],["Unfurnished"],["Unfurnished"],["Unfurnished"],["Unfurnished"],["Unfurnished"],["Semi-Furnished"],["Semi-Furnished"],["Unfurnished"],["Furnished"],["Unfurnished"],["Unfurnished"],["Furnished"],["Semi-Furnished"],["Unfurnished"],["Unfurnished"],["Unfurnished"],["Unfurnished"],["Unfurnished"],["Unfurnished"],["Unfurnished"],["Semi-Furnished"],["Unfurnished"],["Semi-Furnished"],["S
# ...

# %%
fig = px.pie(data,names='Area Type',title='Area Type',color_discrete_sequence=px.colors.sequential.Aggrnyl)
fig.show()
# Out:
# <div>                            <div id="9fd03cc2-fb2a-4646-a1f3-1761d0b11dae" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9fd03cc2-fb2a-4646-a1f3-1761d0b11dae")) {                    Plotly.newPlot(                        "9fd03cc2-fb2a-4646-a1f3-1761d0b11dae",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Area Type=%{label}<extra></extra>","labels":["Super Area","Super Area","Super Area","Super Area","Carpet Area","Super Area","Super Area","Super Area","Carpet Area","Carpet Area","Carpet Area","Carpet Area","Carpet Area","Carpet Area","Carpet Area","Carpet Area","Super Area","Super Area","Carpet Area","Super Area","Carpet Area","Carpet Area","Carpet Area","Super Area","Super Area","Super Area","Carpet Area",
# ...

# %% [markdown]
# The number of Super Area is higher than all of the areas.

# %%
plt.figure(figsize=(10,7))
sns.histplot(data.Rent,kde=True)
plt.show()

# %%
df=data.copy()
df
# Out:
#        Posted On  BHK   Rent  Size            Floor    Area Type  \
# 0     2022-05-18    2  10000  1100  Ground out of 2   Super Area
# 1     2022-05-13    2  20000   800       1 out of 3   Super Area
# 2     2022-05-16    2  17000  1000       1 out of 3   Super Area
# 3     2022-07-04    2  10000   800       1 out of 2   Super Area
# 4     2022-05-09    2   7500   850       1 out of 2  Carpet Area
# ...          ...  ...    ...   ...              ...          ...
# 4741  2022-05-18    2  15000  1000       3 out of 5  Carpet Area
# 4742  2022-05-15    3  29000  2000       1 out of 4   Super Area
# 4743  2022-07-10    3  35000  1750       3 out of 5  Carpet Area
# 4744  2022-07-06    3  45000  1500     23 out of 34  Carpet Area
# 4745  2022-05-04    2  15000  1000       4 out of 5  Carpet Area
#
#                  Area Locality       City Furnishing Status  Tenant Preferred  \
# 0                       Bandel    Kolkata       Unfurnished  Bachelors/Family
# ...

# %%
df['Rent']=np.log1p(df['Rent'])

# %%
plt.scatter(x= 'Floor' , y='Rent' ,data= df , alpha=0.9)

# %%
sns.boxplot(df['Rent'])
# Out:
# <AxesSubplot:>

# %%
sns.barplot(x='BHK',y='Rent',data=df)
# Out:
# <AxesSubplot:xlabel='BHK', ylabel='Rent'>

# %% [markdown]
# The Average Rent of the 5BHK is the highest compared to all.

# %%
sns.barplot(data=df, x="City", y="Rent")
# Out:
# <AxesSubplot:xlabel='City', ylabel='Rent'>

# %% [markdown]
# he Average Rent of Mumbai House is the Highest than all of the Cities

# %%
sns.histplot(data=df, x="Point of Contact", kde=False)
# Out:
# <AxesSubplot:xlabel='Point of Contact', ylabel='Count'>

# %% [markdown]
# the most common point of contact is contact owner

# %%
sns.barplot(data=df, x="Bathroom", y="Rent")
# Out:
# <AxesSubplot:xlabel='Bathroom', ylabel='Rent'>

# %%
sns.catplot(
    data=df, x="Area Type", y="Rent", col="Furnishing Status",
    kind="bar", height=4, aspect=.8,
)

# %%
sns.scatterplot(data=df, x="Point of Contact", y="Rent")
# Out:
# <AxesSubplot:xlabel='Point of Contact', ylabel='Rent'>

# %%
df['Rent']=np.exp(df['Rent'])
df['Rent'].value_counts()
# Out:
# 15001.0    275
# 10001.0    248
# 12001.0    238
# 20001.0    175
# 8001.0     162
#           ...
# 4601.0       1
# 79501.0      1
# 76001.0      1
# 45003.0      1
# 5801.0       1
# Name: Rent, Length: 243, dtype: int64

# %% [markdown]
# # Encoding the object Dataset

# %%
df.describe(include = "object")
# Out:
#          Posted On       Floor   Area Type Area Locality    City  \
# count         4746        4746        4746          4746    4746
# unique          81         480           3          2235       6
# top     2022-07-06  1 out of 2  Super Area   Bandra West  Mumbai
# freq           311         379        2446            37     972
#
#        Furnishing Status  Tenant Preferred Point of Contact
# count               4746              4746             4746
# unique                 3                 3                3
# top       Semi-Furnished  Bachelors/Family    Contact Owner
# freq                2251              3444             3216

# %%
df.drop(['Area Locality','Floor','Posted On'], axis=1, inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
cols = ['Area Type', 'City','Furnishing Status','Tenant Preferred','Point of Contact',]

df[cols] = df[cols].apply(LabelEncoder().fit_transform)

# %%
plt.figure(figsize = (12,8))
sns.heatmap(df.corr() , annot = True , cmap = "YlGnBu")
# Out:
# <AxesSubplot:>

# %% [markdown]
# # train test split

# %%
from sklearn.model_selection import train_test_split

# %%
x=df.drop('Rent',axis=1).values
y=df['Rent'].values

# %%
x_train ,x_test ,y_train ,y_test=train_test_split(x,y ,test_size=0.2,random_state=42)

# %%
x_train.shape
# Out:
# (3796, 8)

# %%
x_test.shape
# Out:
# (950, 8)

# %% [markdown]
# # Modeling

# %% [markdown]
# # RandomForestRegressor

# %%
from sklearn.preprocessing import StandardScaler

# %%
ss=StandardScaler()
x_train =ss.fit_transform(x_train )
x_test=ss.transform(x_test)

# %%
from sklearn.ensemble import RandomForestRegressor
random_forest=RandomForestRegressor()
random_forest.fit(x_train , y_train)
print("Random Forest Training Accuracy:", random_forest.score(x_train , y_train))
print("Random Forest Testing Accuracy:", random_forest.score(x_test , y_test))
# Out:
# Random Forest Training Accuracy: 0.8662245161623991
# Random Forest Testing Accuracy: 0.5165083016784331

# %%
y_pred = random_forest.predict(x_test)
y_pred

y_pred = random_forest.predict(x_test)
df3 = pd.DataFrame({"Y_test": y_test , "Y_pred" : y_pred})
df3.head(20)
# Out:
#       Y_test         Y_pred
# 0    16001.0   17168.313025
# 1    12001.0   17210.648623
# 2    28001.0   31857.666667
# 3     8001.0   48415.000000
# 4    46001.0   89516.000000
# 5    17001.0   16950.595238
# 6    57001.0   55308.666667
# 7     9501.0   12920.608586
# 8   400001.0  314211.000000
# 9    15001.0   12333.315476
# 10   10001.0   14162.583333
# 11   12001.0   10367.166667
# 12   27001.0   17962.666667
# 13   16001.0   14681.476190
# 14   15001.0   21812.000000
# 15    8501.0   29431.000000
# 16  140001.0  105014.333333
# 17   12001.0    8248.551803
# 18    6001.0   16688.920635
# 19   60001.0   39131.500000

# %%
plt.figure(figsize= (20,6))

plt.plot(df3[:500])
plt.legend(["Actual" , "Predicted"])

# %%
from sklearn.metrics import mean_absolute_error , mean_absolute_percentage_error , mean_squared_error

mse = mean_squared_error (y_test , y_pred)
print (mse)

mae = mean_absolute_error (y_test , y_pred)
print (mae)

mape = mean_absolute_percentage_error (y_test , y_pred)
print (mape)
# Out:
# 1926898781.4991093
# 13931.407816437259
# 0.39656103478952065
